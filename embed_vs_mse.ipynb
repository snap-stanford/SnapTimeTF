# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
embeds = [8, 16, 32, 64, 128, 256]
mses = [0.048238963252160608, 0.033518407662571102, 0.02509685115440901, 0.021404449331480037, 0.020434830895907374, 0.020326188681095526]

plt.plot(embeds, mses)
